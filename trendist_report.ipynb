# %%
import pandas as pd
from trendist_toolkit import trends 
import yfinance as yf
# %load_ext autoreload
# %autoreload 2

# %%
history = yf.Ticker('^FCHI').history('10y').Close
history.index = pd.to_datetime(history.index, utc=True)
history.index = history.index.tz_localize(None)

# %%
trend = trends(history=history, threshold=0.05, timeperiod='B').fit()

# %%
trend.plot_trend()

# %%
trend.get_proba('Length')
# Out:
# {'Last length': '58.00',
#  'Last return': '0.05%',
#  'Trend description': {'count': 59.0,
#   'mean': 60.932203389830505,
#   'std': 63.05057204115233,
#   'min': 6.0,
#   '25%': 21.0,
#   '50%': 37.0,
#   '75%': 72.0,
#   'max': 314.0},
#  'Distribution parameters': {'Shape': 5.690488978137819,
#   'Loc': -253.22345209421457,
#   'Scale': 259.2234520942145},
#  'KS test': {'Statitics': 0.0862479017041905, 'P-value': 0.7397565394249858},
#  'Continuation proba': 0.3533347969663449}

# %%
trend.plot_distrib('Length')

# %%
trend.plot_cumdistrib('Length')
